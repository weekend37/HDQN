# %%
import sys
import numpy as np
import random
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
import math
import glob
import io
import os
import base64
from collections import deque
from collections import namedtuple
import pickle 

display
from IPython.display import HTML
from IPython import display as ipythondisplay
from pyvirtualdisplay import Display
import logging

# gym
import gym
from gym import logger as gymlogger
from gym.wrappers import Monitor
gymlogger.set_level(40) #error only

# Local .py files
from visualization import *
from DQN import *
from DQN_utils import *
from DQN_agent import *
from HDQN import *
from HDQN_2head import *
from HDQN_agent import *

# for auto-reloading external modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Running on", device)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Running on cpu

# %%
def load_learning_curves(name='hdqn_learning_curves'):
  with open(CHECKPOINT_FOLDERNAME + name + '.pkl', 'rb') as f:
    return pickle.load(f)

prefix = "vanilla_dqn"
name = prefix + "_" + "learning_curves"
lc = load_learning_curves(name=name)

window = 2
plot_option_ratio(lc['option_ratio'], window)
# Out:
# {'train': [290.0], 'mean_train': [290.0], 'val': {0: 210.0}, 'losses': [array(0.00064886, dtype=float32), array(0.03163147, dtype=float32), array(0.00086587, dtype=float32), array(0.00132516, dtype=float32), array(0.0009725, dtype=float32), array(0.0003341, dtype=float32), array(0.00018687, dtype=float32), array(0.03085789, dtype=float32), array(6.511382e-05, dtype=float32), array(4.7360274e-05, dtype=float32), array(3.656527e-05, dtype=float32), array(2.2813332e-05, dtype=float32), array(1.9784718e-05, dtype=float32), array(0.03129537, dtype=float32), array(2.6047857e-05, dtype=float32), array(5.0669027e-05, dtype=float32), array(5.814303e-05, dtype=float32), array(6.106586e-05, dtype=float32), array(0.03051076, dtype=float32), array(0.00015605, dtype=float32), array(0.03020672, dtype=float32), array(0.00040696, dtype=float32), array(0.00042276, dtype=float32), array(0.00044038, dtype=float32), array(0.03016379, dtype=float32), array(0.03020318, dtype=float32), array(0.03017005, dtype=float32), array(0.05939503, dtype=float32), array(0.0588534, dtype=float32), array(0.0862671, dtype=float32), array(0.08768831, dtype=float32), array(0.10888918, dtype=float32), array(0.03817047, dtype=float32), array(0.05861761, dtype=float32), array(0.03656393, dtype=float32), array(0.03352712, dtype=float32), array(0.0865851, dtype=float32), array(0.11050001, dtype=float32), array(0.05764687, dtype=float32), array(0.13812204, dtype=float32), array(0.03120586, dtype=float32), array(0.02958784, dtype=float32), array(0.10799637, dtype=float32), array(0.13527323, dtype=float32), array(0.10280633, dtype=float32), array(0.09827214, dtype=float32), array(0.12023139, dtype=float32), array(0.15112083, dtype=float32), array(0.08706477, dtype=float32), array(0.13176914, dtype=float32), array(0.096594, dtype=float32), array(0.11418684, dtype=float32), array(0.08206256, dtype=float32), array(0.0581704, dtype=float32), array(0.04836734, dtype=float32), array(0.03588748, dtype=float32), array(0.05774019, dtype=float32), array(0.03298905, dtype=float32), array(0.0308004, dtype=float32), array(0.03012664, dtype=float32), array(0.08863145, dtype=float32), array(0.0304252, dtype=float32), array(0.03074582, dtype=float32), array(0.06184847, dtype=float32), array(0.12274929, dtype=float32), array(0.03108602, dtype=float32), array(0.00021051, dtype=float32), array(0.00030246, dtype=float32), array(0.06038246, dtype=float32), array(0.00042394, dtype=float32), array(0.08967639, dtype=float32), array(0.02980581, dtype=float32), array(0.00079012, dtype=float32), array(0.05853685, dtype=float32), array(0.05825736, dtype=float32), array(0.08595282, dtype=float32), array(0.14027058, dtype=float32), array(0.0837536, dtype=float32), array(0.00580924, dtype=float32), array(0.05738224, dtype=float32), array(0.08139426, dtype=float32), array(0.10603211, dtype=float32), array(0.10646076, dtype=float32), array(0.10458448, dtype=float32), array(0.16957419, dtype=float32), array(0.08811512, dtype=float32), array(0.12280985, dtype=float32), array(0.17880663, dtype=float32), array(0.16639593, dtype=float32), array(0.08982093, dtype=float32), array(0.11480963, dtype=float32), array(0.07242606, dtype=float32), array(0.08394139, dtype=float32), array(0.12757912, dtype=float32), array(0.10747969, dtype=float32), array(0.08201165, dtype=float32), array(0.08272092, dtype=float32), array(0.08236504, dtype=float32), array(0.00532304, dtype=float32), array(0.08392022, dtype=float32), array(0.08487751, dtype=float32), array(0.08490857, dtype=float32), array(0.05737011, dtype=float32), array(0.0850846, dtype=float32), array(0.05760359, dtype=float32), array(0.05757549, dtype=float32), array(0.03063771, dtype=float32), array(0.05750889, dtype=float32), array(0.0030759, dtype=float32), array(0.05726779, dtype=float32), array(0.00286586, dtype=float32), array(0.00324655, dtype=float32), array(0.00297686, dtype=float32), array(0.00291626, dtype=float32), array(0.0023238, dtype=float32), array(0.0 ...
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-116-1095b43fb29c> in <module>
#      10
#      11 window = 2
# ---> 12 plot_option_ratio(lc['option_ratio'], window)
#
# KeyError: 'option_ratio'

# %%
plt.plot(lc['losses']['meta'])
plt.show()
plt.hist(lc['losses']['meta'])
plt.show()
for o in range(4):
    plt.plot(lc['losses'][o], label="option"+str(o), alpha=0.5)
plt.legend()
plt.show()

# %%
env = gym.make("MsPacman-v0")
# hdqn = HDQN(env, learning_rate=2.5e-7, device=device, checkpoint_path=CHECKPOINT_FOLDERNAME)
hdqn = HDQN_2head(env, learning_rate=2.5e-7, device=device, checkpoint_path=CHECKPOINT_FOLDERNAME)
pth = CHECKPOINT_FOLDERNAME + prefix + "_" + 'checkpoint_'+str(100)+'_eps.pth'
hdqn.load_state_dict(torch.load(pth))
# hdqn.current_option = 3
r = play_with_network(env, hdqn, option_len=50)
# Out:
# /Users/helgi/opt/anaconda3/envs/pacman/lib/python3.6/site-packages/gym/envs/registration.py:14: PkgResourcesDeprecationWarning: Parameters to load are deprecated.  Call .resolve and .require separately.
#   result = entry_point.load(False)
#  Playing frame 1210
# <video alt="test" autoplay
#                 loop controls style="height: 400px;">
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#               </video>

# %%
env = gym.make("MsPacman-v0")

dqn = DQN(env, learning_rate=1e-3, device=device)

rewards = []
for n_eps in np.arange(100, 2600, 100):
  pth = CHECKPOINT_FOLDERNAME+'checkpoint_'+str(n_eps)+'_eps.pth'
  dqn.load_state_dict(torch.load(pth))
  r = play_with_network(env, dqn, show_vid=False)
  rewards += [r]

plt.plot(rewards)
plt.show()

# %%
pth = CHECKPOINT_FOLDERNAME+'checkpoint_'+str(1900)+'_eps.pth'
dqn.load_state_dict(torch.load(pth))
r = play_with_network(env, dqn)
